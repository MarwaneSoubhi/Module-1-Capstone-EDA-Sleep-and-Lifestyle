# %%
import pandas as pd 
import numpy as np

# %%
df_main = pd.read_csv(r'C:\Users\REBUILD\Downloads\Sleep_health_and_lifestyle_dataset.csv')

# %%
df_main.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df_main.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df_main['Occ'].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
#  What is the repartition of the data set by BMI ? (Pie Chart/Violion plot)
#
#  What is the average duration of sleep by gender / age ? (Bar Chart)
#
#  What is proportion of people having sleep disorder ? (Pie Chart)
#
#  In average people who have a good score in 'quality of sleep' how many hours do they sleep ? (Box Plot)
#
#  What are the top 5 'Occupation' who sleep the worst ? And the best ? (Horizontal Barchart)
#
#  What is the averga eheartrate for a good sleeper and abad sleeper ? (Bar Chart)

# %% [markdown]
# ### Relational Analysis
#
# It would interesting to investigiate a little bit more to find features influence more the quality of sleep
#
# So let's check that

# %% [markdown]
# Is there a correlation between Physical activity level and quality of sleep ? And with stress ? (Scatter Plot)

# %% [markdown]
# How does stress influence quality of sleep ? And the duration of sleep ? (Violin plot ? to show the distribution)

# %% [markdown]
# Does people with a higher heart rate sleep less/worst ? (Heatmap ?)

# %% [markdown]
# Does people how practice a physical activity sleep better/longer ? (Bar chart or heat map)

# %% [markdown]
# ### By Group
#
# The quality of sleep by BMI
#
# The quality of sleep by Occupation
#
# Duration of sleep by age
